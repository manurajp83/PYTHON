# %%
a,b,c=2,3,0 # variable declaration
print("a=%d b=%d"%(a,b))
print("Arithmetic operators")
print("--------------------")
print("Sum",a+b)
print("Product",a*b)
print("Power",a**b)
print("Integer Devision",a//b)
print("----------------------")
print("Comparison Operator")
print("----------------------")
print("equality[%d==%d]:%s"%(a,b,a==b))
print("not equal[%d!=%d]:%s"%(a,b,a!=b))
print("greater than [%d>%d]:%s"%(a,b,a>b))
print("less than [%d<%d]:%s"%(a,b,a<b))
print("greater than or equal to [%d>=%d]:%s"%(a,b,a>=b))
print("less than [%d<=%d]:%s"%(a,b,a<=b))
print("------------------------")
print("Assignment Operator")
print("------------------------")
c=a
print("c=a",c)
a+=a
print("a+=a",a)
a-=a
print("a-=a",a)
b*=b
print("b*=b",b)
b//b
print("b//b",b)
b%=b
print("b%b",b)
print("-------------------------")
print("Logical Operator")
print(5>4 and 4>3) #logical AND
print(5<4 or 5<6) #logical OR
print(not(a>b) and (b>c)) #logical NOT
print("-------------------------")
print("identity and membership operators")
print("-------------------------")
print(type(3)is int)
print(type(1.3)is not float)
print('n' in "hello world")
print('n' not in "hello world")
print("-------------------------")
print("bitwise operators")
print("-------------------------")
print("~10",~10) #bitwise NOT
print("16&13",16&13)#bitwise AND
print("16/13",16/13)#bitwise OR
print("16^13",16^13)#bitwise XOR
print("16<<3",16<<3)#bitwise shift left
print("16>>3",16>>3)#bitwise shift right
# Out:
# a=2 b=3
# Arithmetic operators
# --------------------
# Sum 5
# Product 6
# Power 8
# Integer Devision 0
# ----------------------
# Comparison Operator
# ----------------------
# equality[2==3]:False
# not equal[2!=3]:True
# greater than [2>3]:False
# less than [2<3]:True
# greater than or equal to [2>=3]:False
# less than [2<=3]:True
# ------------------------
# Assignment Operator
# ------------------------
# c=a 2
# a+=a 4
# a-=a 0
# b*=b 9
# b//b 9
# b%b 0
# -------------------------
# Logical Operator
# True
# True
# False
# -------------------------
# identity and membership operators
# -------------------------
# True
# False
# False
# True
# -------------------------
# bitwise operators
# -------------------------
# ~10 -11
# 16&13 0
# 16/13 1.2307692307692308
# 16^13 29
# 16<<3 128
# 16>>3 2
